# %% [markdown]
# # Object Oriented Programming in Python

# %%
dir(list)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
karibu = 9 
print(type(karibu))
# Out:
# <class 'int'>

# %%
class Employee:
    """
    A class to represent an employee.

    States : 
    - name 
    - salary

    Behaviours: 
    - file returns
    """
    def __init__(self, name, salary):
        self.name = name 
        self.salary = salary

# %%
emp001 = Employee("Isabel Merie", 890000)

# %%
emp002 = Employee("Itangishaka John", 450000)

# %%
print(emp001.name)
# Out:
# Isabel Merie

# %% [markdown]
# ### Class Level Attributes

# %%
class Student: 
    """
    This is a blueprint for all student objects at Zindua School

    Behaviours:
    - Attend Classes

    State: 
     - name 
     - email
     - phone number
     - deposit
    """
    deposit_amount = 5000

    def __init__(self, name, email, phone_number, deposit):
        self.name = name 
        self.email = email
        self.phone_number = phone_number

        if deposit > Student.deposit_amount:
            self.deposit = Student.deposit_amount
        else:
            self.deposit = Student.deposit_amount

# %%
Student001 = Student("Itangishaka", "mwanyumbabrayan@gmail.com", 7891324567, 200000)

# %%
print(Student001.deposit)
# Out:
# 5000

# %% [markdown]
# - This approach is an example of `Encapsulation` where Data and methods are grouped within the class.
#
# - By Definition `Encapsulation` is grouping data and methods together.

# %% [markdown]
# ### Updating the deposit_amount for `student1673`

# %%
Student1673 = Student("Nadia", "fahari@heza.co.ke", 7891324567, 5000)

# %%
Student1673.deposit_amount = 3000

# %%
print(Student1673.deposit_amount)
# Out:
# 3000

# %%
print(Student001.deposit_amount)
# Out:
# 5000

# %% [markdown]
# - A security pespective here is We don't want a scenario where changing data in a single instance results to changes to data in other instances from a class
